# %% [markdown]
# # 實作股價K線圖
# 台積電 TSMC (2330) <br>
# 聯發科 MediaTek (2454)

# %%
import pandas as pd
import datetime as dt
import pandas_datareader as pdr

start = dt.datetime(2020, 1, 1)
end = dt.datetime(2020, 6, 1)
df_2330 = pdr.DataReader('2330.TW', 'yahoo', start=start, end=end)
df_2454 = pdr.DataReader('2454.TW', 'yahoo', start=start, end=end)
print(df_2330.head())
print(df_2454 .head())
# Out:
#              High    Low   Open  Close      Volume   Adj Close
# Date
# 2020-01-02  339.0  332.5  332.5  339.0  31754120.0  328.295837
# 2020-01-03  345.0  335.5  344.0  339.5  41811268.0  328.780060
# 2020-01-06  334.5  332.0  333.0  332.0  45343057.0  321.516846
# 2020-01-07  333.0  326.5  332.5  329.5  50879181.0  319.095795
# 2020-01-08  333.0  325.0  325.0  329.5  37567748.0  319.095795
#              High    Low   Open  Close    Volume   Adj Close
# Date
# 2020-01-02  446.0  440.5  445.0  441.5   6237434  433.574982
# 2020-01-03  445.5  423.0  445.0  434.5  12375266  426.700653
# 2020-01-06  431.5  424.0  428.0  424.0   8448516  416.389130
# 2020-01-07  431.0  418.0  428.0  426.0  11707155  418.353210
# 2020-01-08  436.5  424.0  426.0  430.5   9695448  422.772461

# %%
GOOG=pdr.DataReader('GOOG',data_source='yahoo', start=start, end=end)
GOOG.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-12-31  1338.000000  1329.084961  1330.109985  1337.020020   961800
# 2020-01-02  1368.140015  1341.550049  1341.550049  1367.369995  1406600
# 2020-01-03  1372.500000  1345.543945  1347.859985  1360.660034  1186400
# 2020-01-06  1396.500000  1350.000000  1350.000000  1394.209961  1732300
# 2020-01-07  1402.989990  1390.380005  1397.939941  1393.339966  1502700
#
#               Adj Close
# Date
# 2019-12-31  1337.020020
# 2020-01-02  1367.369995
# 2020-01-03  1360.660034
# 2020-01-06  1394.209961
# 2020-01-07  1393.339966

# %% [markdown]
# ### 台積電 VS 聯發科 股價線圖

# %%
import matplotlib.pyplot as plt
#from pandas.plotting import register_matplotlib_converters
#register_matplotlib_converters()

fig = plt.figure(figsize=(10, 6))
plt.plot(df_2330.Close, label='TSMC')
plt.plot(df_2454.Close, label='MediaTek')
plt.title('TSMC vs MediaTek', loc='center')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True, axis='y')
plt.legend()
plt.show()

# %% [markdown]
# ### 台積電股價K線圖
# 繪製股價圖表套件 mplfinance <br>
# Github 網址：https://github.com/matplotlib/mplfinance
